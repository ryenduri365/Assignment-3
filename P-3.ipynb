# %% [markdown]
# # Student ID-916467534

# %%
import pandas as pd
import csv
from pathlib import Path
import seaborn as sns
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
te = TransactionEncoder()
data_array=[]
file_path='/Users/Assignment-1/Grocery_Items_67.csv'
with open(file_path, 'r') as file:
    csv_reader = csv.reader(file,None)
    header = next(csv_reader, None)
    
    for row in csv_reader:
        filtered_row = [cell for cell in row if cell.strip() != '']
        data_array.append(filtered_row)
te_ary = te.fit(data_array).transform(data_array)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
data_array
# Out:
# [['long life bakery product', 'butter milk'],
#  ['rolls/buns', 'chocolate'],
#  ['domestic eggs', 'rolls/buns'],
#  ['rolls/buns', 'other vegetables'],
#  ['onions', 'frozen vegetables', 'curd'],
#  ['beef', 'newspapers', 'misc. beverages'],
#  ['liver loaf', 'fruit/vegetable juice'],
#  ['yogurt', 'rolls/buns'],
#  ['domestic eggs', 'berries'],
#  ['brown bread',
#   'whole milk',
#   'spread cheese',
#   'butter',
#   'fruit/vegetable juice'],
#  ['bottled beer', 'semi-finished bread'],
#  ['domestic eggs', 'sugar'],
#  ['sausage', 'chicken', 'margarine', 'yogurt'],
#  ['soda', 'root vegetables', 'semi-finished bread'],
#  ['rolls/buns', 'bottled water', 'whole milk'],
#  ['fruit/vegetable juice', 'long life bakery product'],
#  ['tropical fruit', 'rolls/buns', 'candy'],
#  ['butter milk', 'canned beer'],
#  ['soda', 'root vegetables'],
#  ['newspapers', 'cat food'],
#  ['other vegetables', 'soda'],
#  ['whole milk', 'pip fruit'],
#  ['root vegetables', 'processed cheese', 'yogurt'],
#  ['sausage', 'curd'],
#  ['candy', 'berries', 'mustard'],
#  ['pastry', 'waffles'],
#  ['chocolate', 'other vegetables'],
#  ['specialty bar', 'misc. beverages'],
#  ['ice cream', 'other vegetables'],
#  ['citrus fruit', 'sparkling wine', 'bottled water'],
#  ['root vegetables', 'soda'],
#  ['sausage', 'root vegetables'],
#  ['other vegetables', 'pip fruit', 'napkins'],
#  ['margarine', 'cereals'],
#  ['whole milk',
#   'beef',
#   'tropical fruit',
#   'tropical fruit',
#   'whole milk',
#   'domestic eggs',
#   'coffee',
#   'other vegetables'],
#  ['Instant food products', 'pip fruit'],
#  ['other vegetables', 'canned fish'],
#  ['other vegetables', 'whole milk'],
#  ['butter', 'onions', 'butter milk'],
#  ['citrus fruit', 'whole milk', 'pastry', 'other vegetables'],
#  ['fruit/vegetable juice', 'salt'],
#  ['bottled beer', 'hygiene articles'],
#  ['tropical fruit', 'root vegetables'],
#  ['bottled beer', 'nut snack'],
#  ['rolls/buns', 'other vegetables'],
#  ['rolls/buns', 'canned vegetables', 'cat food'],
#  ['pork', 'citrus fruit', 'UHT-milk', 'dessert'],
#  ['root vegetables', 'soda'],
#  ['bottled water', 'citrus fruit', 'butter', 'whole milk'],
#  ['pip fruit', 'whipped/sour cream'],
#  ['canned beer', 'whole milk'],
#  ['dessert', 'soda'],
#  ['citrus fruit', 'whole milk', 'bottled beer'],
#  ['sausage', 'soda', 'curd', 'house keeping products'],
#  ['other vegetables', 'mustard', 'soups'],
#  ['dessert', 'curd', 'whole milk', 'bottled water'],
#  ['yogurt', 'whole milk'],
#  ['frankfurter', 'pip fruit', 'rolls/buns', 'onions'],
#  ['citrus fruit', 'hamburger meat'],
#  ['grapes', 'pip fruit', 'photo/film', 'root vegetables', 'cling film/bags'],
#  ['pork', 'coffee', 'margarine'],
#  ['UHT-milk', 'tea'],
#  ['soft cheese', 'other vegetables'],
#  ['tropical fruit', 'sausage'],
#  ['ham', 'curd'],
#  ['canned beer', 'newspapers'],
#  ['soda', 'other vegetables', 'frozen vegetables'],
#  ['rolls/buns', 'whole milk'],
#  ['soda', 'shopping bags', 'other vegetables', 'rolls/buns'],
#  ['hygiene articles', 'cling film/bags'],
#  ['rolls/buns', 'cream cheese '],
#  ['beef', 'newspapers'],
#  ['hamburger meat', 'whipped/sour cream'],
#  ['other vegetables', 'rolls/buns'],
#  ['coffee', 'sausage', 'shopping bags', 'specialty bar', 'red/blush wine'],
#  ['sausage',
#   'root vegetables',
#   'bottled beer',
#   'butter',
#   'whole milk',
#   'newspapers',
#   'yogurt'],
#  ['other vegetables', 'bottled water'],
#  ['pip fruit', 'fruit/vegetable juice'],
#  ['other vegetables', 'rolls/buns', 'frozen meals'],
#  ['other vegetables', 'hard cheese'],
#  ['soda', 'waffles'],
#  ['yogurt', 'specialty chocolate', 'specialty bar'],
#  ['yogurt', 'margarine'],
#  ['newspapers', 'long life bakery product'],
#  ['pip fruit', 'spices'],
#  ['tropical fruit', 'yogurt'],
#  ['whole milk', 'hair spray', 'butter', 'pastry'],
#  ['liver loaf',
#   'rolls/buns',
#   'rolls/buns',
#   'other vegetables',
#   'rolls/buns',
#   'packaged fruit/vegetables',
#   'flower (seeds)',
#   'shopping bags'],
#  ['whole milk', 'dessert'],
#  ['dessert', 'newspapers', 'bottled water'],
#  ['ice cream', 'other vegetables'],
#  ['mayonnaise', 'decalcifier'],
#  ['other vegetables', 'fruit/vegetable juice'],
#  ['root vegetables', 'frozen potato products'],
#  ['other vegetables', 'whole milk'],
#  ['beverages', 'candles'],
#  ['yogurt', 'whipped/sour cream'],
#  ['waffles', 'cling film/bags'],
#  ['other vegetables', 'sliced cheese'],
#  ['whole milk', 'chocolate'],
#  ['white bread', 'meat', 'domestic eggs', 'roll products '],
#  ['red/blush wine', 'canned fish'],
#  ['frozen potato products', 'detergent'],
#  ['berries', 'semi-finished bread'],
#  ['ham', 'curd'],
#  ['other vegetables', 'berries', 'whipped/sour cream'],
#  ['cream cheese ', 'chocolate'],
#  ['frankfurter', 'white bread'],
#  ['bottled water', 'frankfurter', 'dessert', 'root vegetables'],
#  ['pip fruit', 'cat food'],
#  ['chicken', 'frozen meals', 'napkins'],
#  ['citrus fruit', 'toilet cleaner'],
#  ['butter milk',
#   'chocolate',
#   'berries',
#   'sweet spreads',
#   'butter',
#   'long life bakery product',
#   'napkins',
#   'white bread'],
#  ['brown bread', 'whole milk'],
#  ['domestic eggs', 'mayonnaise', 'coffee'],
#  ['coffee', 'pip fruit'],
#  ['cooking chocolate', 'hygiene articles'],
#  ['beef', 'butter'],
#  ['ice cream', 'canned beer'],
#  ['hard cheese', 'coffee'],
#  ['frozen dessert', 'canned beer'],
#  ['sausage', 'soda', 'pastry', 'flower (seeds)', 'newspapers'],
#  ['whole milk', 'bottled beer'],
#  ['yogurt', 'frozen meals'],
#  ['soda', 'soda'],
#  ['cream cheese ', 'bottled water', 'rolls/buns'],
#  ['chicken', 'frozen fish', 'sugar'],
#  ['sausage', 'other vegetables'],
#  ['fruit/vegetable juice', 'other vegetables'],
#  ['soda', 'dessert', 'shopping bags'],
#  ['pickled vegetables', 'liquor'],
#  ['sausage', 'bottled beer'],
#  ['rolls/buns', 'cream cheese '],
#  ['pastry', 'whole milk'],
#  ['citrus fruit', 'sweet spreads'],
#  ['whole milk', 'baking powder'],
#  ['whole milk', 'pip fruit'],
#  ['frankfurter', 'chicken', 'processed cheese', 'dessert'],
#  ['sausage', 'tea'],
#  ['butter milk',
#   'ham',
#   'whole milk',
#   'chicken',
#   'domestic eggs',
#   'shopping bags',
#   'chewing gum',
#   'shopping bags',
#   'white bread'],
#  ['cereals', 'frozen vegetables'],
#  ['other vegetables', 'whole milk'],
#  ['other vegetables', 'ice cream', 'pork', 'salt'],
#  ['bottled water', 'rolls/buns', 'domestic eggs'],
#  ['tropical fruit', 'citrus fruit', 'domestic eggs', 'root vegetables'],
#  ['waffles', 'rolls/buns'],
#  ['whole milk', 'waffles', 'shopping bags'],
#  ['beef', 'whole milk', 'chewing gum'],
#  ['other vegetables', 'sausage', 'white bread', 'soda'],
#  ['whole milk', 'yogurt'],
#  ['newspapers', 'salty snack'],
#  ['newspapers', 'rolls/buns'],
#  ['rolls/buns', 'condensed milk', 'whole milk', 'soda'],
#  ['other vegetables', 'dessert'],
#  ['other vegetables', 'yogurt'],
#  ['frankfurter', 'brown bread'],
#  ['hard cheese', 'root vegetables', 'white bread'],
#  ['red/blush wine', 'shopping bags'],
#  ['oil', 'soda'],
#  ['frankfurter', 'hamburger meat'],
#  ['other vegetables', 'sugar'],
#  ['chicken', 'sausage', 'domestic eggs', 'pasta'],
#  ['soda', 'sausage', 'yogurt', 'root vegetables'],
#  ['tropical fruit', 'nuts/prunes'],
#  ['sweet spreads', 'male cosmetics'],
#  ['grapes', 'chicken'],
#  ['white wine', 'canned vegetables'],
#  ['ham', 'tropical fruit', 'popcorn'],
#  ['soda', 'misc. beverages'],
#  ['dessert', 'flower (seeds)'],
#  ['tropical fruit', 'whole milk', 'fruit/vegetable juice', 'whole milk'],
#  ['frankfurter', 'other vegetables'],
#  ['pip fruit', 'butter', 'whole milk', 'other vegetables'],
#  ['tropical fruit', 'whole milk', 'nut snack', 'sliced cheese'],
#  ['canned beer', 'pip fruit', 'instant coffee', 'yogurt'],
#  ['butter', 'root vegetables'],
#  ['pip fruit', 'domestic eggs'],
#  ['citrus fruit', 'soda'],
#  ['sausage', 'pastry', 'soda'],
#  ['canned beer',
#   'frankfurter',
#   'chicken',
#   'whole milk',
#   'softener',
#   'vinegar'],
#  ['beef', 'pork', 'margarine', 'fruit/vegetable juice', 'margarine'],
#  ['ham', 'brown bread'],
#  ['other vegetables', 'popcorn', 'butter'],
#  ['bottled beer', 'whole milk'],
#  ['salty snack', 'shopping bags'],
#  ['soda', 'rolls/buns'],
#  ['frozen vegetables', 'canned beer'],
#  ['soda', 'bottled beer'],
#  ['frankfurter', 'other vegetables'],
#  ['margarine', 'brown bread'],
#  ['sugar', 'brown bread'],
#  ['margarine', 'beef', 'whipped/sour cream'],
#  ['sausage', 'pip fruit', 'dish cleaner'],
#  ['tropical fruit', 'tropical fruit', 'napkins'],
#  ['frankfurter', 'berries'],
#  ['beverages', 'sugar'],
#  ['rolls/buns', 'dessert', 'coffee'],
#  ['chocolate', 'citrus fruit', 'yogurt'],
#  ['canned beer', 'bottled beer', 'yogurt', 'fruit/vegetable juice'],
#  ['dessert', 'rolls/buns'],
#  ['tropical fruit', 'hamburger meat', 'bottled beer', 'yogurt'],
#  ['shopping bags', 'rolls/buns'],
#  ['pip fruit', 'onions', 'yogurt'],
#  ['citrus fruit', 'other vegetables'],
#  ['misc. beverages', 'soda'],
#  ['brown bread', 'frozen dessert'],
#  ['shopping bags', 'root vegetables'],
#  ['ham', 'sausage', 'detergent', 'whipped/sour cream', 'yogurt', 'dishes'],
#  ['frankfurter', 'other vegetables', 'whole milk', 'ready soups', 'brandy'],
#  ['flower soil/fertilizer', 'waffles'],
#  ['root vegetables', 'chocolate'],
#  ['frankfurter', 'curd'],
#  ['rolls/buns', 'root vegetables'],
#  ['whole milk', 'citrus fruit'],
#  ['other vegetables', 'rolls/buns'],
#  ['soda', 'UHT-milk', 'newspapers', 'white bread'],
#  ['soft cheese', 'cream cheese '],
#  ['pip fruit', 'curd'],
#  ['whole milk', 'hard cheese', 'white bread'],
#  ['citrus fruit', 'pastry', 'other vegetables', 'pastry'],
#  ['citrus fruit', 'soda'],
#  ['dessert', 'margarine'],
#  ['tropical fruit',
#   'sausage',
#   'beef',
#   'yogurt',
#   'long life bakery product',
#   'yogurt',
#   'cream cheese ',
#   'processed cheese'],
#  ['sugar', 'soda'],
#  ['frozen vegetables', 'chicken'],
#  ['other vegetables', 'red/blush wine'],
#  ['canned fish', 'specialty cheese', 'yogurt', 'specialty vegetables'],
#  ['sausage', 'sausage'],
#  ['bottled water', 'salty snack', 'brown bread'],
#  ['liquor', 'UHT-milk'],
#  ['canned beer',
#   'pork',
#   'processed cheese',
#   'root vegetables',
#   'snack products',
#   'sugar'],
#  ['bottled beer', 'ice cream'],
#  ['domestic eggs', 'whole milk', 'napkins'],
#  ['frankfurter', 'cat food'],
#  ['whole milk', 'beverages', 'frozen fruits', 'fruit/vegetable juice'],
#  ['soda', 'other vegetables'],
#  ['yogurt', 'pip fruit'],
#  ['whole milk', 'whole milk'],
#  ['soda', 'red/blush wine'],
#  ['chicken', 'white bread'],
#  ['tropical fruit', 'cake bar', 'soda', 'cat food'],
#  ['dessert', 'dog food', 'newspapers'],
#  ['rolls/buns', 'pickled vegetables', 'chocolate', 'whole milk'],
#  ['house keeping products', 'yogurt'],
#  ['butter', 'frozen meals'],
#  ['hair spray', 'chocolate', 'rolls/buns'],
#  ['other vegetables', 'pip fruit', 'frozen vegetables'],
#  ['bottled water', 'butter milk'],
#  ['meat', 'specialty cheese'],
#  ['berries', 'hygiene articles'],
#  ['pork', 'pickled vegetables'],
#  ['berries', 'grapes', 'onions'],
#  ['whipped/sour cream', 'hard cheese'],
#  ['fruit/vegetable juice', 'coffee'],
#  ['other vegetables', 'beverages'],
#  ['butter', 'dish cleaner'],
#  ['newspapers', 'cat food'],
#  ['chocolate', 'chocolate'],
#  ['chewing gum', 'beef', 'domestic eggs'],
#  ['tropical fruit', 'ice cream', 'butter milk', 'domestic eggs'],
#  ['white bread', 'liquor (appetizer)', 'shopping bags'],
#  ['sausage', 'chicken', 'canned beer', 'pip fruit'],
#  ['whipped/sour cream', 'newspapers'],
#  ['other vegetables', 'rice', 'specialty fat'],
#  ['onions', 'specialty chocolate'],
#  ['meat', 'citrus fruit', 'chocolate', 'pastry', 'rolls/buns'],
#  ['white bread', 'yogurt'],
#  ['tropical fruit', 'cooking chocolate'],
#  ['berries', 'tropical fruit', 'whole milk', 'soda'],
#  ['pip fruit', 'butter'],
#  ['whole milk', 'domestic eggs'],
#  ['rolls/buns', 'canned beer'],
#  ['root vegetables', 'margarine', 'bottled water'],
#  ['sugar', 'coffee'],
#  ['pip fruit', 'pip fruit', 'sliced cheese', 'dishes'],
#  ['rolls/buns', 'shopping bags'],
#  ['sausage', 'pip fruit'],
#  ['sausage', 'frozen fruits'],
#  ['frankfurter',
#   'root vegetables',
#   'pastry',
#   'napkins',
#   'long life bakery product'],
#  ['chicken', 'canned beer'],
#  ['meat', 'coffee'],
#  ['bottled water', 'yogurt'],
#  ['pastry',
#   'hamburger meat',
#   'newspapers',
#   'other vegetables',
#   'root vegetables',
#   'instant coffee',
#   'yogurt',
#   'domestic eggs'],
#  ['rolls/buns', 'citrus fruit', 'fruit/vegetable juice'],
#  ['pork', 'pastry'],
#  ['zwieback', 'curd'],
#  ['butter milk', 'pet care'],
#  ['dessert', 'shopping bags'],
#  ['canned beer', 'frozen meals', 'pastry'],
#  ['beverages', 'cat food'],
#  ['whole milk', 'root vegetables'],
#  ['other vegetables', 'salty snack'],
#  ['bottled water', 'bottled water'],
#  ['finished products', 'berries'],
#  ['whipped/sour cream', 'soda'],
#  ['beef', 'onions'],
#  ['other vegetables', 'butter'],
#  ['root vegetables', 'pastry'],
#  ['other vegetables', 'hygiene articles'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['tropical fruit', 'rolls/buns', 'fruit/vegetable juice'],
#  ['whole milk', 'oil', 'soups'],
#  ['waffles', 'shopping bags', 'soda', 'cream cheese '],
#  ['chocolate marshmallow', 'yogurt', 'soda'],
#  ['tropical fruit', 'rolls/buns', 'canned beer', 'dish cleaner'],
#  ['citrus fruit', 'canned fruit', 'pip fruit', 'dessert'],
#  ['tropical fruit', 'curd'],
#  ['curd', 'photo/film'],
#  ['ham', 'pastry'],
#  ['other vegetables', 'specialty chocolate', 'newspapers'],
#  ['citrus fruit', 'tropical fruit', 'soda', 'coffee', 'domestic eggs'],
#  ['dessert', 'margarine'],
#  ['pork', 'soda'],
#  ['hard cheese', 'soda'],
#  ['soda', 'flower (seeds)'],
#  ['other vegetables', 'whole milk'],
#  ['canned beer', 'other vegetables', 'yogurt'],
#  ['sausage', 'other vegetables', 'oil', 'candy'],
#  ['rolls/buns', 'root vegetables', 'rolls/buns', 'long life bakery product'],
#  ['whole milk', 'white wine'],
#  ['pip fruit', 'white wine', 'shopping bags'],
#  ['chicken', 'whole milk'],
#  ['beverages', 'canned fish'],
#  ['whole milk', 'beef', 'canned beer'],
#  ['butter', 'baking powder', 'brown bread'],
#  ['other vegetables', 'white bread'],
#  ['bottled water',
#   'oil',
#   'sausage',
#   'bottled beer',
#   'rolls/buns',
#   'bottled water',
#   'waffles',
#   'tropical fruit',
#   'frozen meals'],
#  ['whole milk', 'white bread', 'frozen vegetables'],
#  ['root vegetables', 'red/blush wine'],
#  ['citrus fruit', 'misc. beverages', 'misc. beverages'],
#  ['rolls/buns', 'bottled water'],
#  ['other vegetables', 'bottled beer'],
#  ['whole milk', 'cream cheese '],
#  ['pork', 'root vegetables', 'rolls/buns'],
#  ['bottled beer', 'soda'],
#  ['coffee', 'butter milk'],
#  ['frankfurter',
#   'beef',
#   'meat',
#   'waffles',
#   'whole milk',
#   'curd',
#   'white bread',
#   'frozen meals',
#   'sugar'],
#  ['pip fruit',
#   'curd',
#   'canned beer',
#   'pork',
#   'bottled beer',
#   'frozen dessert',
#   'dessert',
#   'bottled water'],
#  ['beef', 'other vegetables'],
#  ['salt', 'ice cream', 'yogurt', 'canned beer'],
#  ['beverages', 'jam'],
#  ['cream cheese ', 'shopping bags', 'shopping bags'],
#  ['whole milk', 'yogurt', 'chocolate'],
#  ['bottled beer', 'tropical fruit'],
#  ['chicken', 'yogurt'],
#  ['pork', 'cake bar'],
#  ['root vegetables', 'detergent'],
#  ['pork', 'chocolate', 'soap'],
#  ['salty snack', 'canned beer'],
#  ['frankfurter', 'sausage'],
#  ['pasta', 'hamburger meat', 'dessert', 'bottled water'],
#  ['pork', 'root vegetables'],
#  ['tropical fruit', 'citrus fruit'],
#  ['whole milk', 'yogurt'],
#  ['sausage', 'whole milk', 'bottled water'],
#  ['bottled beer', 'soda'],
#  ['whole milk',
#   'citrus fruit',
#   'shopping bags',
#   'white wine',
#   'soda',
#   'yogurt'],
#  ['specialty bar', 'bottled water'],
#  ['citrus fruit', 'dessert'],
#  ['soda', 'chocolate'],
#  ['packaged fruit/vegetables', 'specialty bar'],
#  ['tropical fruit',
#   'grapes',
#   'chocolate marshmallow',
#   'yogurt',
#   'red/blush wine',
#   'brown bread'],
#  ['citrus fruit', 'yogurt'],
#  ['beef', 'yogurt', 'fruit/vegetable juice'],
#  ['other vegetables', 'whipped/sour cream'],
#  ['beef', 'tropical fruit'],
#  ['pip fruit', 'coffee'],
#  ['rolls/buns', 'shopping bags'],
#  ['sausage', 'chicken', 'bottled beer', 'whole milk'],
#  ['whole milk', 'soft cheese', 'soda', 'brown bread'],
#  ['whole milk', 'tropical fruit', 'margarine'],
#  ['sugar', 'napkins'],
#  ['pastry', 'cereals'],
#  ['pot plants', 'yogurt', 'cream cheese '],
#  ['pork', 'soda', 'rolls/buns', 'brown bread'],
#  ['root vegetables', 'whipped/sour cream', 'frozen potato products', 'sugar'],
#  ['whole milk', 'bottled beer'],
#  ['onions', 'long life bakery product'],
#  ['dessert', 'cream cheese '],
#  ['tropical fruit', 'soda', 'frozen meals'],
#  ['sausage', 'butter', 'whole milk'],
#  ['whole milk', 'root vegetables'],
#  ['pork', 'grapes', 'hygiene articles'],
#  ['specialty cheese', 'meat', 'cat food', 'bottled beer', 'newspapers'],
#  ['whole milk', 'sauces', 'hard cheese'],
#  ['frozen potato products', 'bottled beer'],
#  ['tropical fruit', 'yogurt'],
#  ['ham', 'white wine', 'pasta'],
#  ['soda', 'butter'],
#  ['whole milk', 'root vegetables'],
#  ['specialty chocolate', 'other vegetables'],
#  ['photo/film', 'canned beer'],
#  ['chicken', 'margarine'],
#  ['citrus fruit', 'bottled water'],
#  ['other vegetables', 'bottled water', 'cereals'],
#  ['canned beer', 'domestic eggs'],
#  ['beef', 'candy'],
#  ['shopping bags', 'salty snack'],
#  ['beef', 'curd'],
#  ['ham', 'chocolate marshmallow'],
#  ['frankfurter', 'light bulbs', 'rolls/buns', 'pasta'],
#  ['chicken', 'whole milk', 'newspapers'],
#  ['chocolate', 'whole milk'],
#  ['cream cheese ', 'canned beer', 'waffles'],
#  ['chicken', 'bottled water'],
#  ['specialty cheese', 'misc. beverages'],
#  ['whole milk', 'rolls/buns'],
#  ['whole milk', 'pastry'],
#  ['butter milk', 'rolls/buns'],
#  ['margarine', 'other vegetables', 'bottled water', 'meat spreads'],
#  ['other vegetables', 'coffee'],
#  ['liquor', 'canned beer'],
#  ['tropical fruit', 'UHT-milk'],
#  ['curd', 'beef', 'napkins'],
#  ['frankfurter', 'processed cheese'],
#  ['sausage', 'whipped/sour cream'],
#  ['frankfurter',
#   'beverages',
#   'beef',
#   'whole milk',
#   'other vegetables',
#   'rolls/buns',
#   'softener',
#   'vinegar',
#   'white bread'],
#  ['soda', 'pip fruit', 'sugar', 'brown bread'],
#  ['rolls/buns', 'yogurt'],
#  ['root vegetables', 'mustard'],
#  ['frankfurter', 'ketchup'],
#  ['chicken', 'whole milk', 'snack products'],
#  ['beef', 'whipped/sour cream'],
#  ['other vegetables', 'curd'],
#  ['hamburger meat', 'chocolate', 'processed cheese'],
#  ['bottled beer', 'butter milk'],
#  ['ice cream', 'onions'],
#  ['dog food', 'hygiene articles', 'Instant food products'],
#  ['meat', 'butter'],
#  ['tropical fruit',
#   'root vegetables',
#   'pip fruit',
#   'butter milk',
#   'waffles',
#   'bottled beer'],
#  ['UHT-milk', 'shopping bags'],
#  ['whole milk', 'hamburger meat', 'detergent', 'pickled vegetables'],
#  ['domestic eggs', 'soda'],
#  ['soda', 'soda'],
#  ['waffles', 'instant coffee'],
#  ['whole milk', 'sliced cheese'],
#  ['tropical fruit', 'whole milk'],
#  ['sausage', 'domestic eggs'],
#  ['whole milk', 'pasta'],
#  ['rolls/buns', 'oil', 'beverages', 'bottled water'],
#  ['instant coffee', 'domestic eggs'],
#  ['soft cheese', 'semi-finished bread'],
#  ['sugar', 'shopping bags', 'instant coffee'],
#  ['beef', 'yogurt'],
#  ['beverages', 'yogurt'],
#  ['dessert', 'pot plants'],
#  ['chicken',
#   'meat',
#   'chewing gum',
#   'bottled beer',
#   'baking powder',
#   'shopping bags'],
#  ['shopping bags', 'citrus fruit', 'whole milk', 'sliced cheese'],
#  ['dessert', 'sugar'],
#  ['semi-finished bread', 'other vegetables', 'soda'],
#  ['whipped/sour cream', 'bottled water'],
#  ['tropical fruit', 'semi-finished bread'],
#  ['long life bakery product', 'hamburger meat', 'whole milk'],
#  ['pip fruit', 'whole milk', 'soda'],
#  ['tropical fruit', 'salty snack'],
#  ['tropical fruit', 'frozen potato products', 'vinegar'],
#  ['soda', 'fruit/vegetable juice'],
#  ['dessert', 'yogurt'],
#  ['soda', 'dish cleaner'],
#  ['root vegetables', 'tropical fruit'],
#  ['pip fruit', 'rolls/buns', 'shopping bags'],
#  ['hamburger meat', 'spread cheese', 'pasta'],
#  ['other vegetables', 'prosecco', 'pot plants'],
#  ['whole milk', 'cream cheese '],
#  ['pastry', 'whole milk'],
#  ['hamburger meat', 'rolls/buns'],
#  ['whole milk', 'roll products '],
#  ['rolls/buns', 'soda', 'chocolate', 'soda'],
#  ['tropical fruit', 'oil'],
#  ['meat', 'margarine'],
#  ['sugar', 'berries'],
#  ['berries', 'whipped/sour cream'],
#  ['sausage', 'rolls/buns'],
#  ['meat spreads', 'hard cheese', 'frozen vegetables', 'butter'],
#  ['chocolate',
#   'oil',
#   'domestic eggs',
#   'fruit/vegetable juice',
#   'frozen vegetables',
#   'rolls/buns'],
#  ['tropical fruit', 'cat food'],
#  ['sausage', 'bottled beer', 'sliced cheese'],
#  ['herbs', 'pip fruit'],
#  ['citrus fruit', 'specialty bar', 'domestic eggs'],
#  ['dessert', 'butter'],
#  ['meat', 'canned fish', 'brown bread'],
#  ['bottled water', 'cream cheese ', 'curd'],
#  ['condensed milk', 'fruit/vegetable juice', 'white wine', 'specialty fat'],
#  ['domestic eggs', 'ham'],
#  ['bottled beer', 'processed cheese'],
#  ['dessert', 'whipped/sour cream'],
#  ['pip fruit', 'other vegetables'],
#  ['canned beer', 'napkins'],
#  ['newspapers', 'coffee'],
#  ['root vegetables', 'waffles', 'whipped/sour cream'],
#  ['whole milk', 'newspapers', 'frozen vegetables'],
#  ['chicken', 'napkins', 'other vegetables', 'newspapers'],
#  ['root vegetables', 'coffee'],
#  ['newspapers', 'citrus fruit'],
#  ['herbs', 'specialty chocolate', 'red/blush wine', 'salad dressing'],
#  ['UHT-milk', 'margarine'],
#  ['liver loaf', 'herbs'],
#  ['yogurt', 'yogurt'],
#  ['curd', 'processed cheese', 'bottled water', 'pickled vegetables'],
#  ['other vegetables', 'shopping bags'],
#  ['root vegetables', 'bottled water'],
#  ['beef', 'tea', 'oil'],
#  ['tropical fruit', 'coffee'],
#  ['pork', 'specialty chocolate'],
#  ['soda', 'soda'],
#  ['other vegetables',
#   'tropical fruit',
#   'white bread',
#   'specialty chocolate',
#   'pot plants',
#   'shopping bags'],
#  ['whole milk',
#   'citrus fruit',
#   'pip fruit',
#   'butter',
#   'grapes',
#   'ice cream',
#   'margarine',
#   'whipped/sour cream'],
#  ['sausage', 'tropical fruit', 'curd'],
#  ['turkey', 'canned beer', 'abrasive cleaner'],
#  ['root vegetables', 'other vegetables'],
#  ['liver loaf', 'other vegetables'],
#  ['roll products ', 'toilet cleaner'],
#  ['hamburger meat', 'packaged fruit/vegetables', 'baking powder'],
#  ['other vegetables', 'misc. beverages', 'root vegetables', 'curd', 'dessert'],
#  ['canned beer', 'whipped/sour cream', 'misc. beverages'],
#  ['packaged fruit/vegetables', 'tea'],
#  ['specialty bar',
#   'tropical fruit',
#   'yogurt',
#   'bottled beer',
#   'baking powder'],
#  ['frankfurter', 'pip fruit'],
#  ['salt', 'citrus fruit'],
#  ['pet care', 'brown bread'],
#  ['pip fruit', 'other vegetables'],
#  ['bottled water', 'butter milk'],
#  ['canned beer', 'other vegetables'],
#  ['pork', 'newspapers', 'root vegetables'],
#  ['turkey', 'whipped/sour cream'],
#  ['other vegetables', 'other vegetables'],
#  ['whole milk', 'shopping bags'],
#  ['other vegetables', 'yogurt', 'salty snack'],
#  ['brown bread', 'bottled beer'],
#  ['whole milk', 'butter'],
#  ['whole milk', 'whipped/sour cream', 'soda'],
#  ['citrus fruit', 'butter'],
#  ['white bread', 'canned beer'],
#  ['female sanitary products', 'salt'],
#  ['pip fruit',
#   'pork',
#   'sausage',
#   'dessert',
#   'grapes',
#   'soda',
#   'dessert',
#   'yogurt',
#   'whole milk'],
#  ['onions', 'soda'],
#  ['soft cheese', 'white wine'],
#  ['butter', 'specialty chocolate'],
#  ['whole milk', 'butter'],
#  ['meat', 'frozen potato products'],
#  ['whole milk', 'canned beer', 'cat food'],
#  ['chicken', 'root vegetables', 'dish cleaner'],
#  ['instant coffee', 'butter'],
#  ['soda', 'rolls/buns', 'soda'],
#  ['root vegetables', 'soups'],
#  ['soda', 'sliced cheese'],
#  ['newspapers', 'long life bakery product', 'napkins'],
#  ['chocolate marshmallow', 'flour'],
#  ['bottled water', 'yogurt', 'butter'],
#  ['frozen dessert', 'pastry'],
#  ['whole milk', 'pork'],
#  ['other vegetables',
#   'other vegetables',
#   'other vegetables',
#   'hamburger meat',
#   'soda',
#   'soft cheese',
#   'waffles'],
#  ['berries', 'rolls/buns'],
#  ['whole milk', 'soda'],
#  ['sausage', 'hamburger meat', 'newspapers'],
#  ['soda', 'curd', 'sliced cheese'],
#  ['ice cream', 'whole milk'],
#  ['tropical fruit', 'shopping bags'],
#  ['pork', 'nuts/prunes', 'rolls/buns'],
#  ['chicken', 'tropical fruit'],
#  ['whole milk', 'other vegetables'],
#  ['butter milk', 'other vegetables'],
#  ['citrus fruit', 'fruit/vegetable juice'],
#  ['curd', 'other vegetables'],
#  ['pork', 'pip fruit'],
#  ['rolls/buns', 'pet care'],
#  ['rum', 'coffee', 'sliced cheese'],
#  ['curd', 'margarine'],
#  ['white bread', 'dog food', 'potato products'],
#  ['canned beer', 'sugar'],
#  ['other vegetables', 'rolls/buns'],
#  ['sausage', 'male cosmetics'],
#  ['frankfurter', 'red/blush wine'],
#  ['other vegetables', 'coffee'],
#  ['salty snack', 'condensed milk'],
#  ['cream cheese ', 'rolls/buns'],
#  ['whisky', 'shopping bags', 'rum'],
#  ['root vegetables', 'white wine', 'bottled water', 'red/blush wine'],
#  ['root vegetables', 'frozen vegetables', 'domestic eggs'],
#  ['pip fruit', 'yogurt'],
#  ['whole milk', 'newspapers'],
#  ['canned beer', 'chocolate'],
#  ['beef', 'citrus fruit', 'napkins', 'semi-finished bread', 'brown bread'],
#  ['misc. beverages', 'cling film/bags'],
#  ['cream cheese ', 'pickled vegetables'],
#  ['kitchen towels', 'bottled beer'],
#  ['newspapers', 'newspapers'],
#  ['yogurt', 'tropical fruit'],
#  ['pork', 'butter'],
#  ['pip fruit', 'onions', 'domestic eggs'],
#  ['newspapers', 'rolls/buns'],
#  ['grapes', 'soda'],
#  ['frankfurter', 'zwieback', 'other vegetables', 'liquor', 'bottled water'],
#  ['other vegetables', 'butter'],
#  ['beef', 'pet care'],
#  ['frankfurter', 'root vegetables'],
#  ['soda', 'other vegetables', 'white bread'],
#  ['bottled beer', 'other vegetables', 'butter'],
#  ['domestic eggs', 'UHT-milk'],
#  ['other vegetables', 'white bread', 'whole milk'],
#  ['female sanitary products', 'margarine'],
#  ['whipped/sour cream', 'yogurt'],
#  ['UHT-milk', 'other vegetables'],
#  ['hygiene articles', 'white bread'],
#  ['salty snack', 'condensed milk'],
#  ['long life bakery product', 'semi-finished bread'],
#  ['citrus fruit', 'pet care'],
#  ['other vegetables', 'long life bakery product'],
#  ['bottled water', 'other vegetables'],
#  ['frozen fish', 'beef'],
#  ['sausage', 'bottled beer', 'hygiene articles'],
#  ['whole milk', 'rolls/buns'],
#  ['white bread', 'frozen vegetables'],
#  ['tropical fruit', 'baking powder'],
#  ['citrus fruit', 'tropical fruit', 'root vegetables', 'soda'],
#  ['liver loaf', 'canned beer', 'tropical fruit', 'canned vegetables'],
#  ['other vegetables', 'oil'],
#  ['citrus fruit', 'tropical fruit'],
#  ['ice cream', 'dishes'],
#  ['cream cheese ', 'whipped/sour cream'],
#  ['UHT-milk', 'tropical fruit'],
#  ['whole milk', 'citrus fruit'],
#  ['specialty bar', 'chewing gum'],
#  ['soda', 'domestic eggs'],
#  ['meat', 'processed cheese', 'root vegetables', 'cat food'],
#  ['butter milk', 'margarine'],
#  ['beverages', 'shopping bags'],
#  ['whole milk', 'rolls/buns'],
#  ['butter milk', 'bottled beer'],
#  ['shopping bags', 'tropical fruit', 'red/blush wine'],
#  ['frankfurter', 'bottled water'],
#  ['long life bakery product', 'other vegetables'],
#  ['onions', 'whole milk'],
#  ['citrus fruit', 'onions'],
#  ['ham', 'spread cheese'],
#  ['citrus fruit', 'yogurt'],
#  ['bottled beer', 'fruit/vegetable juice', 'fruit/vegetable juice'],
#  ['onions', 'sugar', 'mustard', 'rolls/buns'],
#  ['brown bread', 'newspapers'],
#  ['yogurt', 'soda', 'yogurt'],
#  ['canned beer', 'whole milk', 'bottled beer'],
#  ['other vegetables', 'domestic eggs'],
#  ['margarine', 'domestic eggs'],
#  ['frankfurter', 'bottled beer', 'other vegetables', 'bottled beer'],
#  ['newspapers', 'processed cheese'],
#  ['rolls/buns', 'packaged fruit/vegetables'],
#  ['other vegetables',
#   'tropical fruit',
#   'onions',
#   'cream cheese ',
#   'root vegetables',
#   'root vegetables',
#   'yogurt'],
#  ['whole milk', 'margarine', 'rolls/buns'],
#  ['beef', 'flour'],
#  ['citrus fruit', 'root vegetables'],
#  ['whole milk', 'whole milk', 'candles'],
#  ['ice cream', 'fruit/vegetable juice'],
#  ['hamburger meat', 'rolls/buns'],
#  ['coffee', 'yogurt'],
#  ['whipped/sour cream', 'yogurt'],
#  ['soda', 'cling film/bags'],
#  ['root vegetables', 'fruit/vegetable juice'],
#  ['chicken', 'frozen vegetables', 'candy'],
#  ['frankfurter', 'packaged fruit/vegetables'],
#  ['whole milk', 'fruit/vegetable juice'],
#  ['tropical fruit', 'whole milk'],
#  ['dessert', 'spread cheese'],
#  ['berries', 'specialty bar'],
#  ['ice cream', 'beef', 'yogurt', 'canned beer'],
#  ['beef', 'white wine', 'pip fruit'],
#  ['canned beer', 'sugar'],
#  ['butter milk', 'specialty fat'],
#  ['shopping bags', 'whipped/sour cream'],
#  ['ham', 'fruit/vegetable juice', 'chocolate'],
#  ['whole milk', 'detergent'],
#  ['margarine', 'rolls/buns', 'root vegetables'],
#  ['pip fruit', 'ice cream', 'newspapers', 'pastry'],
#  ['tropical fruit', 'whole milk'],
#  ['root vegetables', 'cream cheese '],
#  ['dish cleaner',
#   'whole milk',
#   'flower (seeds)',
#   'flour',
#   'chewing gum',
#   'dog food'],
#  ['frankfurter', 'whole milk'],
#  ['pork', 'cream cheese '],
#  ['other vegetables', 'tropical fruit'],
#  ['long life bakery product',
#   'long life bakery product',
#   'whipped/sour cream',
#   'soda'],
#  ['butter', 'male cosmetics', 'newspapers'],
#  ['sausage',
#   'zwieback',
#   'sliced cheese',
#   'other vegetables',
#   'bottled beer',
#   'soda'],
#  ['UHT-milk', 'canned fish'],
#  ['other vegetables', 'soda', 'yogurt'],
#  ['root vegetables', 'salty snack'],
#  ['canned fish', 'cream cheese '],
#  ['onions', 'other vegetables'],
#  ['root vegetables', 'yogurt', 'bottled water'],
#  ['roll products ', 'rice'],
#  ['ice cream', 'butter'],
#  ['soft cheese', 'long life bakery product'],
#  ['citrus fruit', 'tropical fruit', 'soda', 'bottled water'],
#  ['yogurt', 'pot plants'],
#  ['other vegetables', 'chocolate'],
#  ['citrus fruit', 'chocolate'],
#  ['other vegetables', 'root vegetables', 'bottled water'],
#  ['root vegetables', 'pickled vegetables'],
#  ['whole milk', 'whole milk'],
#  ['other vegetables', 'sugar'],
#  ['packaged fruit/vegetables', 'specialty cheese', 'margarine', 'margarine'],
#  ['butter', 'candy'],
#  ['tropical fruit', 'soda', 'canned beer'],
#  ['seasonal products', 'white wine'],
#  ['hamburger meat', 'hygiene articles', 'soda', 'tropical fruit'],
#  ['other vegetables', 'canned fish'],
#  ['citrus fruit', 'red/blush wine'],
#  ['bottled beer', 'jam', 'male cosmetics', 'dessert'],
#  ['butter', 'bottled beer'],
#  ['salty snack', 'butter'],
#  ['canned beer', 'whole milk', 'onions', 'coffee'],
#  ['pasta', 'whole milk', 'waffles'],
#  ['grapes', 'grapes'],
#  ['photo/film', 'bottled water'],
#  ['mayonnaise', 'curd'],
#  ['bottled beer', 'rolls/buns', 'soda'],
#  ['liquor', 'butter milk'],
#  ['bottled beer', 'tropical fruit', 'domestic eggs', 'baking powder'],
#  ['citrus fruit', 'coffee'],
#  ['softener', 'salty snack'],
#  ['tropical fruit', 'salty snack'],
#  ['citrus fruit', 'pastry', 'salt'],
#  ['curd', 'tropical fruit'],
#  ['canned beer', 'frozen vegetables'],
#  ['chocolate', 'rolls/buns'],
#  ['tropical fruit', 'whole milk'],
#  ['chicken', 'citrus fruit'],
#  ['whole milk', 'napkins', 'pastry', 'long life bakery product'],
#  ['hygiene articles', 'pastry'],
#  ['whole milk',
#   'pastry',
#   'seasonal products',
#   'berries',
#   'long life bakery product',
#   'yogurt',
#   'coffee'],
#  ['rolls/buns', 'shopping bags'],
#  ['berries', 'beverages'],
#  ['rolls/buns', 'yogurt'],
#  ['bottled beer', 'rolls/buns'],
#  ['frankfurter', 'shopping bags', 'bottled water'],
#  ['tropical fruit', 'detergent'],
#  ['photo/film', 'chewing gum'],
#  ['UHT-milk', 'whole milk'],
#  ['pastry', 'whole milk', 'citrus fruit', 'newspapers'],
#  ['root vegetables', 'ice cream'],
#  ['tropical fruit', 'whipped/sour cream'],
#  ['brown bread', 'chocolate'],
#  ['butter', 'rolls/buns'],
#  ['chicken', 'other vegetables'],
#  ['coffee', 'frozen vegetables'],
#  ['whole milk', 'pip fruit'],
#  ['sausage',
#   'tropical fruit',
#   'frozen vegetables',
#   'other vegetables',
#   'shopping bags'],
#  ['UHT-milk', 'whole milk', 'newspapers', 'domestic eggs'],
#  ['pastry', 'other vegetables'],
#  ['bottled beer', 'brown bread'],
#  ['other vegetables', 'instant coffee', 'instant coffee', 'hygiene articles'],
#  ['pork', 'soda'],
#  ['hamburger meat', 'pet care', 'pastry'],
#  ['sausage', 'soda'],
#  ['tropical fruit', 'onions'],
#  ['newspapers', 'chocolate'],
#  ['soups', 'specialty bar', 'soda', 'whipped/sour cream'],
#  ['pip fruit', 'butter'],
#  ['canned beer', 'organic sausage', 'tropical fruit', 'shopping bags'],
#  ['chocolate', 'frankfurter', 'yogurt', 'margarine', 'canned vegetables'],
#  ['rolls/buns', 'other vegetables'],
#  ['frankfurter', 'other vegetables', 'specialty bar'],
#  ['sausage', 'curd', 'fruit/vegetable juice'],
#  ['beef', 'root vegetables', 'butter milk'],
#  ['citrus fruit', 'pot plants', 'pot plants'],
#  ['root vegetables', 'citrus fruit'],
#  ['soda', 'whole milk'],
#  ['sausage', 'chocolate', 'newspapers', 'pastry'],
#  ['ham', 'whole milk'],
#  ['semi-finished bread', 'whole milk'],
#  ['oil', 'butter'],
#  ['hard cheese', 'butter'],
#  ['root vegetables', 'whole milk'],
#  ['cream cheese ', 'cream cheese '],
#  ['roll products ', 'specialty chocolate'],
#  ['sausage', 'beverages'],
#  ['sausage',
#   'other vegetables',
#   'citrus fruit',
#   'curd',
#   'red/blush wine',
#   'dessert',
#   'specialty chocolate',
#   'white bread',
#   'pastry'],
#  ['canned vegetables', 'whole milk'],
#  ['soda', 'sliced cheese', 'butter'],
#  ['tropical fruit', 'chocolate'],
#  ['pork', 'flour'],
#  ['sausage', 'detergent', 'hygiene articles'],
#  ['sausage', 'coffee', 'yogurt', 'white wine'],
#  ['pip fruit', 'shopping bags'],
#  ['pastry', 'meat spreads'],
#  ['whole milk', 'soda', 'tea'],
#  ['fruit/vegetable juice', 'ketchup'],
#  ['beef', 'whole milk', 'fruit/vegetable juice', 'hygiene articles'],
#  ['root vegetables', 'shopping bags'],
#  ['pork', 'sugar'],
#  ['frankfurter', 'hard cheese'],
#  ['other vegetables', 'bottled beer'],
#  ['other vegetables', 'other vegetables', 'whole milk'],
#  ['salty snack', 'whole milk'],
#  ['frozen vegetables', 'frozen vegetables'],
#  ['other vegetables', 'rolls/buns', 'root vegetables'],
#  ['bottled water', 'soda'],
#  ['yogurt', 'butter'],
#  ['whipped/sour cream', 'whipped/sour cream'],
#  ['pastry', 'baking powder'],
#  ['spread cheese', 'specialty chocolate', 'sugar'],
#  ['butter', 'whole milk'],
#  ['beef', 'bottled water'],
#  ['canned beer', 'pip fruit'],
#  ['other vegetables', 'hard cheese', 'chocolate'],
#  ['root vegetables', 'rolls/buns', 'salty snack'],
#  ['long life bakery product', 'curd', 'pot plants', 'soda'],
#  ['soda', 'soda'],
#  ['coffee', 'whole milk', 'mustard'],
#  ['brown bread', 'whipped/sour cream'],
#  ['long life bakery product', 'hard cheese'],
#  ['artif. sweetener', 'herbs'],
#  ['tropical fruit', 'other vegetables'],
#  ['dessert', 'meat'],
#  ['rolls/buns', 'soda', 'chocolate'],
#  ['hard cheese', 'Instant food products'],
#  ['specialty bar', 'condensed milk'],
#  ['other vegetables', 'kitchen towels'],
#  ['UHT-milk', 'bottled beer', 'domestic eggs', 'rolls/buns'],
#  ['chicken', 'soups', 'bottled water'],
#  ['sliced cheese', 'other vegetables'],
#  ['pot plants', 'chicken'],
#  ['condensed milk', 'berries', 'tea', 'frozen vegetables', 'cat food'],
#  ['root vegetables', 'other vegetables'],
#  ['shopping bags', 'soda'],
#  ['coffee', 'hard cheese'],
#  ['chocolate', 'long life bakery product'],
#  ['meat', 'pork'],
#  ['frankfurter', 'canned fish'],
#  ['shopping bags', 'canned beer'],
#  ['hamburger meat', 'other vegetables'],
#  ['whole milk', 'napkins'],
#  ['chicken', 'whole milk'],
#  ['whole milk', 'bottled beer'],
#  ['chicken', 'rolls/buns'],
#  ['UHT-milk', 'coffee'],
#  ['meat', 'dessert'],
#  ['rolls/buns', 'shopping bags'],
#  ['sliced cheese', 'pasta'],
#  ['canned beer', 'whole milk', 'other vegetables'],
#  ['citrus fruit', 'other vegetables'],
#  ['bottled beer', 'whole milk'],
#  ['canned beer', 'tropical fruit', 'kitchen towels'],
#  ['photo/film', 'onions'],
#  ['pork', 'curd'],
#  ['ice cream', 'napkins'],
#  ['whole milk', 'frozen potato products', 'fruit/vegetable juice'],
#  ['beverages', 'pickled vegetables'],
#  ['domestic eggs', 'whole milk', 'artif. sweetener'],
#  ['pork', 'beverages', 'frozen fish'],
#  ['root vegetables', 'softener'],
#  ['other vegetables', 'rolls/buns'],
#  ['frankfurter', 'whole milk', 'shopping bags', 'rolls/buns'],
#  ['tropical fruit', 'pastry'],
#  ['misc. beverages', 'dessert', 'spread cheese', 'onions', 'coffee'],
#  ['beef', 'frozen meals', 'white bread'],
#  ['whole milk', 'sugar'],
#  ['pork', 'oil'],
#  ['root vegetables', 'butter', 'frozen vegetables', 'butter'],
#  ['soda', 'butter milk', 'citrus fruit', 'other vegetables'],
#  ['chicken', 'abrasive cleaner'],
#  ['pet care', 'cake bar'],
#  ['misc. beverages', 'rolls/buns'],
#  ['yogurt', 'rolls/buns', 'soda'],
#  ['white bread', 'curd cheese'],
#  ['pork', 'whipped/sour cream'],
#  ['beef', 'whole milk', 'newspapers'],
#  ['red/blush wine', 'frozen fish'],
#  ['cooking chocolate', 'red/blush wine', 'cleaner'],
#  ['root vegetables',
#   'tropical fruit',
#   'bottled water',
#   'white bread',
#   'processed cheese',
#   'yogurt',
#   'beverages'],
#  ['newspapers', 'salty snack'],
#  ['white wine', 'specialty bar'],
#  ['root vegetables', 'packaged fruit/vegetables'],
#  ['canned vegetables', 'chocolate marshmallow'],
#  ['root vegetables', 'chocolate', 'candy'],
#  ['citrus fruit', 'frozen vegetables', 'margarine'],
#  ['canned beer', 'grapes', 'whole milk', 'dessert'],
#  ['spread cheese', 'rolls/buns'],
#  ['hamburger meat', 'root vegetables'],
#  ['yogurt', 'frozen potato products'],
#  ['onions', 'whipped/sour cream'],
#  ['meat', 'coffee'],
#  ['frankfurter', 'whole milk'],
#  ['white wine', 'fruit/vegetable juice'],
#  ['canned beer', 'yogurt', 'bottled water'],
#  ['meat spreads', 'tropical fruit', 'rolls/buns'],
#  ['salty snack', 'white wine'],
#  ['tropical fruit', 'detergent', 'rolls/buns', 'coffee'],
#  ['beverages', 'cake bar'],
#  ['other vegetables', 'whole milk', 'artif. sweetener'],
#  ['soft cheese', 'rolls/buns', 'detergent'],
#  ['yogurt', 'sparkling wine'],
#  ['root vegetables', 'whole milk'],
#  ['citrus fruit', 'soda', 'butter', 'bottled water', 'bottled beer'],
#  ['coffee', 'canned fish'],
#  ['root vegetables', 'margarine'],
#  ['sausage', 'tropical fruit', 'bottled beer', 'fruit/vegetable juice'],
#  ['onions', 'canned fruit'],
#  ['pastry', 'brown bread'],
#  ['tropical fruit', 'frozen dessert'],
#  ['prosecco', 'onions'],
#  ['cleaner', 'curd'],
#  ['root vegetables', 'canned beer'],
#  ['frankfurter', 'detergent', 'chocolate'],
#  ['margarine', 'frozen meals', 'dish cleaner', 'yogurt'],
#  ['rolls/buns', 'canned beer'],
#  ['pork', 'whole milk'],
#  ['tropical fruit', 'whole milk', 'whole milk', 'potato products'],
#  ['hard cheese', 'whipped/sour cream'],
#  ['canned beer', 'tropical fruit', 'margarine'],
#  ['hard cheese', 'bottled water'],
#  ['tropical fruit', 'pastry', 'salty snack'],
#  ['butter milk', 'hygiene articles'],
#  ['sausage', 'root vegetables'],
#  ['citrus fruit', 'fruit/vegetable juice'],
#  ['chewing gum', 'coffee', 'margarine'],
#  ['root vegetables', 'hard cheese'],
#  ['pip fruit', 'sauces'],
#  ['canned beer', 'yogurt'],
#  ['citrus fruit', 'whipped/sour cream'],
#  ['rolls/buns', 'baby cosmetics'],
#  ['bottled water', 'newspapers'],
#  ['citrus fruit', 'fruit/vegetable juice'],
#  ['other vegetables', 'bottled water'],
#  ['UHT-milk', 'root vegetables', 'cake bar'],
#  ['onions', 'whole milk'],
#  ['other vegetables', 'rolls/buns', 'sweet spreads'],
#  ['pip fruit', 'rum'],
#  ['meat', 'whole milk'],
#  ['frozen meals', 'bottled beer', 'root vegetables', 'potato products'],
#  ['root vegetables', 'coffee', 'sliced cheese', 'newspapers'],
#  ['curd', 'frankfurter', 'white bread', 'pip fruit', 'waffles'],
#  ['berries', 'bottled water', 'curd', 'shopping bags'],
#  ['whole milk', 'grapes'],
#  ['soda', 'tropical fruit'],
#  ['sliced cheese', 'skin care'],
#  ['dessert', 'other vegetables', 'other vegetables'],
#  ['bottled beer', 'other vegetables'],
#  ['whole milk', 'other vegetables', 'curd'],
#  ['sugar', 'shopping bags'],
#  ['packaged fruit/vegetables',
#   'root vegetables',
#   'sliced cheese',
#   'pip fruit'],
#  ['other vegetables', 'soda'],
#  ['pot plants', 'packaged fruit/vegetables', 'butter', 'rolls/buns'],
#  ['tropical fruit', 'other vegetables'],
#  ['margarine', 'whole milk'],
#  ['butter milk', 'soda', 'ham', 'bottled beer', 'detergent'],
#  ['candy', 'soda', 'candy'],
#  ['rolls/buns', 'hygiene articles', 'fruit/vegetable juice'],
#  ['root vegetables', 'pet care'],
#  ['waffles', 'brown bread'],
#  ['berries', 'other vegetables'],
#  ['flower soil/fertilizer',
#   'rolls/buns',
#   'yogurt',
#   'ice cream',
#   'whipped/sour cream'],
#  ['whole milk', 'whipped/sour cream'],
#  ['light bulbs', 'cooking chocolate'],
#  ['other vegetables', 'rolls/buns'],
#  ['coffee', 'margarine'],
#  ['pet care', 'pastry'],
#  ['root vegetables', 'newspapers', 'dishes'],
#  ['fruit/vegetable juice', 'packaged fruit/vegetables'],
#  ['hamburger meat', 'tidbits'],
#  ['hamburger meat', 'rolls/buns', 'pip fruit', 'berries'],
#  ['beverages', 'canned beer'],
#  ['margarine', 'coffee', 'sliced cheese'],
#  ['ham', 'tropical fruit', 'frozen meals', 'sparkling wine'],
#  ['beef', 'margarine', 'baking powder'],
#  ['sausage', 'snack products', 'rolls/buns'],
#  ['pork', 'meat'],
#  ['dishes', 'salty snack'],
#  ['ham', 'processed cheese'],
#  ['canned beer', 'onions'],
#  ['whole milk', 'pasta', 'rolls/buns'],
#  ['frankfurter', 'specialty chocolate'],
#  ['chocolate marshmallow', 'brown bread'],
#  ['other vegetables', 'red/blush wine', 'rolls/buns', 'frozen vegetables'],
#  ['pickled vegetables', 'frozen vegetables'],
#  ['rolls/buns', 'waffles'],
#  ['sausage', 'fish'],
#  ['whole milk', 'butter', 'domestic eggs'],
#  ['cat food',
#   'bottled beer',
#   'beef',
#   'brown bread',
#   'margarine',
#   'rolls/buns'],
#  ['abrasive cleaner', 'yogurt', 'frozen meals'],
#  ['bottled beer', 'soups', 'detergent'],
#  ['butter', 'long life bakery product'],
#  ['coffee', 'bottled water', 'roll products '],
#  ['UHT-milk', 'soda'],
#  ['root vegetables', 'butter'],
#  ['beef', 'coffee'],
#  ['other vegetables', 'margarine'],
#  ['chicken', 'bottled beer'],
#  ['root vegetables', 'fruit/vegetable juice'],
#  ['other vegetables', 'dish cleaner'],
#  ['yogurt', 'frozen potato products'],
#  ['pork', 'specialty chocolate'],
#  ['dessert', 'dental care'],
#  ['other vegetables', 'whole milk'],
#  ['rolls/buns', 'long life bakery product'],
#  ['candy', 'specialty fat'],
#  ['bottled water', 'bottled water'],
#  ['yogurt', 'salty snack'],
#  ['soft cheese', 'frozen vegetables'],
#  ['Instant food products', 'whipped/sour cream', 'butter', 'cake bar'],
#  ['other vegetables', 'citrus fruit', 'pork', 'shopping bags'],
#  ['frozen vegetables', 'yogurt', 'shopping bags'],
#  ...]

# %%
df
# Out:
#       Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                     False     False             False             False
# 1                     False     False             False             False
# 2                     False     False             False             False
# 3                     False     False             False             False
# 4                     False     False             False             False
# ...                     ...       ...               ...               ...
# 7995                  False     False             False             False
# 7996                  False     False             False             False
# 7997                  False     False             False             False
# 7998                  False     False             False             False
# 7999                  False     False             False             False
#
#       baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0              False  False          False             False  False    False
# 1              False  False          False             False  False    False
# 2              False  False          False             False  False    False
# 3              False  False          False             False  False    False
# 4              False  False          False             False  False    False
# ...              ...    ...            ...               ...    ...      ...
# 7995           False  False          False             False  False    False
# 7996           False  False          False             False  False    False
# 7997           False  False          False             False  False    False
# 7998           False  False          False             False  False    False
# 7999           False  False          False             False  False    False
#
#       ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0     ...   False    False    False               False   False        False
# 1     ...   False    False    False               False   False        False
# 2     ...   False    False    False               False   False        False
# 3     ...   False    False    False               False   False        False
# 4     ...   False    False    False               False   False        False
# ...   ...     ...      ...      ...                 ...     ...          ...
# 7995  ...   False    False    False               False   False        False
# 7996  ...   False    False    False               False   False        False
# 7997  ...   False    False    False               False   False        False
# 7998  ...   False    False    False               False   False        False
# 7999  ...   False    False    False               False   False        False
#
#       white wine  whole milk  yogurt  zwieback
# 0          False       False   False     False
# 1          False       False   False     False
# 2          False       False   False     False
# 3          False       False   False     False
# 4          False       False   False     False
# ...          ...         ...     ...       ...
# 7995       False       False   False     False
# 7996       False       False   False     False
# 7997       False       False   False     False
# 7998       False        True   False     False
# 7999       False       False   False     False
#
# [8000 rows x 166 columns]

# %%
frequent_itemsets = fpgrowth(df, min_support=0.01, use_colnames=True)

# %%
frequent_itemsets['length']=[len(i) for i in frequent_itemsets['itemsets']]

# %%
frequent_itemsets
# Out:
#      support                        itemsets  length
# 0   0.018125                   (butter milk)       1
# 1   0.017625      (long life bakery product)       1
# 2   0.109500                    (rolls/buns)       1
# 3   0.020750                     (chocolate)       1
# 4   0.037125                 (domestic eggs)       1
# ..       ...                             ...     ...
# 64  0.011000  (rolls/buns, other vegetables)       2
# 65  0.014125        (rolls/buns, whole milk)       2
# 66  0.014625  (other vegetables, whole milk)       2
# 67  0.011375            (yogurt, whole milk)       2
# 68  0.011500              (soda, whole milk)       2
#
# [69 rows x 3 columns]

# %% [markdown]
# # what are the association rules you can extract from your dataset?

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
# Out:
#           antecedents         consequents  antecedent support  \
# 0        (rolls/buns)  (other vegetables)             0.10950
# 1        (rolls/buns)        (whole milk)             0.10950
# 2  (other vegetables)        (whole milk)             0.12300
# 3            (yogurt)        (whole milk)             0.08425
# 4              (soda)        (whole milk)             0.09500
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.123000  0.011000    0.100457  0.816720 -0.002469    0.974939
# 1            0.155625  0.014125    0.128995  0.828886 -0.002916    0.969427
# 2            0.155625  0.014625    0.118902  0.764032 -0.004517    0.958322
# 3            0.155625  0.011375    0.135015  0.867565 -0.001736    0.976173
# 4            0.155625  0.011500    0.121053  0.777848 -0.003284    0.960666
#
#    zhangs_metric
# 0      -0.201280
# 1      -0.188195
# 2      -0.260444
# 3      -0.142878
# 4      -0.239878

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1).shape[0]
# Out:
# 5

# %%
rows=4
cols=3
nd_array = np.zeros((rows, cols), dtype=int)

# %%
nd_array[0,0]
# Out:
# 0

# %%
for count_i, i in enumerate([0.001, 0.005, 0.01, 0.05]):
    for count_j,j in enumerate([0.05, 0.075, 0.1]):
        
        frequent_itemsets = fpgrowth(df, min_support=i, use_colnames=True)
        frequent_itemsets['length']=[len(i) for i in frequent_itemsets['itemsets']]
        nd_array[count_i,count_j]=association_rules(frequent_itemsets, metric="confidence", min_threshold=j).shape[0]
        print(f'msv and mct {i,j} Assocaition rules --{nd_array[count_i,count_j]}')
data = pd.DataFrame(nd_array, columns=[0.05, 0.075, 0.1],index=[0.001, 0.005, 0.01, 0.05])
ax=sns.heatmap(data, annot=True)
ax.set(xlabel="mct", ylabel="msv")
# Out:
# msv and mct (0.001, 0.05) Assocaition rules --529
# msv and mct (0.001, 0.075) Assocaition rules --289
# msv and mct (0.001, 0.1) Assocaition rules --158
# msv and mct (0.005, 0.05) Assocaition rules --64
# msv and mct (0.005, 0.075) Assocaition rules --43
# msv and mct (0.005, 0.1) Assocaition rules --25
# msv and mct (0.01, 0.05) Assocaition rules --10
# msv and mct (0.01, 0.075) Assocaition rules --8
# msv and mct (0.01, 0.1) Assocaition rules --5
# msv and mct (0.05, 0.05) Assocaition rules --0
# msv and mct (0.05, 0.075) Assocaition rules --0
# msv and mct (0.05, 0.1) Assocaition rules --0
# [Text(0.5, 23.52222222222222, 'mct'), Text(50.722222222222214, 0.5, 'msv')]

# %%
nd_array
# Out:
# array([[529, 289, 158],
#        [ 64,  43,  25],
#        [ 10,   8,   5],
#        [  0,   0,   0]])

# %%
frequent_itemsets = fpgrowth(df, min_support=0.005, use_colnames=True)
rules=association_rules(frequent_itemsets, metric="confidence",min_threshold=0.0001)

# %%
rules['confidence'].max()
# Out:
# 0.16449086161879894

# %% [markdown]
# # List the association rule(s) (i.e., one or more rules depending on your dataset) that have the highest confidence for minimum support = 0.005. What is that confidence value?

# %%
rules[rules['confidence']==0.16449086161879894]
# Out:
#        antecedents   consequents  antecedent support  consequent support  \
# 20  (bottled beer)  (whole milk)            0.047875            0.155625
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 20  0.007875    0.164491  1.056969  0.000424    1.010611       0.056609

# %% [markdown]
# # Confidence value - 0.164491

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
import cv2
import pathlib
from tqdm import tqdm
import os
import random
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
# Out:
# /Users/chinmai/miniforge3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes

# %%
path='/Users/Assignment-1/Cropped'

# %%
four_label=['Walker_hound','Boston_bull','Lhasa','flat-coated_retriever']

# %%
desktop = pathlib.Path(path)
files=list(desktop.rglob("*/*"))

# %%
len(files),files[0]
# Out:
# (704,
#  PosixPath('/Users/Assignment-1/Cropped/n02099267-flat-coated_retriever/n02099267_3077-0.jpg'))

# %%
def Label(path):
    file_path = str(Path(path))
    last_separator_index = file_path.rfind('/')
    second_last_separator_index = file_path.rfind('/', 0, last_separator_index)
    breed_folder = file_path[second_last_separator_index + 1:last_separator_index]
    if breed_folder == 'n02099267-flat-coated_retriever':
        breed_folder=breed_folder.split('-')[1]+'-'+breed_folder.split('-')[2]
    else:
        breed_folder=breed_folder.split('-')[1]
    return breed_folder

# %%
num_cls=4
label=[]
img=[]
training=[]
for i in files:
    i=os.path.normpath(i)
    img_array = cv2.imread(i)
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2GRAY)
    new_array = cv2.resize(img_array, (128, 128), interpolation=cv2.INTER_AREA)

    label.append(Label(i))
    img.append(new_array)
paired_elements = list(zip(label, img))
random.shuffle(paired_elements)
shuffled_label, shuffled_img = zip(*paired_elements)

# %%
shuffled_img[0].shape
# Out:
# (128, 128)

# %%
x_train = np.array([row.astype(float)/255 for row in shuffled_img])

# %%
# np.array(shuffled_img).shape

# %%
x_train = np.expand_dims(x_train, -1)

# %%
x_train.shape
# Out:
# (704, 128, 128, 1)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
# label=[four_label.index(i) if i in four_label else None for i in label ]
from keras.utils import to_categorical
label_encoder = LabelEncoder()
numeric_labels = label_encoder.fit_transform(label)
label = to_categorical(numeric_labels)

# %%
label=np.array(label)

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(128,128,1)),
        layers.Conv2D(8, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(16, activation="relu"),
        layers.Dense(num_cls, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 8)       80
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 8)         0
#  D)
#
#  flatten (Flatten)           (None, 31752)             0
#
#  dense (Dense)               (None, 16)                508048
#
#  dense_1 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 508196 (1.94 MB)
# Trainable params: 508196 (1.94 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 8
epochs = 20

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

hist=model.fit(x_train, label, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/20
# 71/71 [==============================] - 1s 9ms/step - loss: 1.3495 - accuracy: 0.2931 - val_loss: 2.3622 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 71/71 [==============================] - 1s 8ms/step - loss: 1.2936 - accuracy: 0.3570 - val_loss: 3.2264 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 71/71 [==============================] - 1s 8ms/step - loss: 1.2356 - accuracy: 0.4192 - val_loss: 1.9645 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 71/71 [==============================] - 1s 8ms/step - loss: 1.1233 - accuracy: 0.5240 - val_loss: 3.1928 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 71/71 [==============================] - 1s 8ms/step - loss: 0.9819 - accuracy: 0.6128 - val_loss: 2.8815 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 71/71 [==============================] - 1s 9ms/step - loss: 0.8486 - accuracy: 0.7229 - val_loss: 3.0487 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 71/71 [==============================] - 1s 13ms/step - loss: 0.7172 - accuracy: 0.7993 - val_loss: 3.8073 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 71/71 [==============================] - 1s 15ms/step - loss: 0.5972 - accuracy: 0.8472 - val_loss: 4.3989 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.4793 - accuracy: 0.9147 - val_loss: 5.6993 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.3748 - accuracy: 0.9218 - val_loss: 5.2641 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.2951 - accuracy: 0.9449 - val_loss: 5.8686 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 71/71 [==============================] - 1s 16ms/step - loss: 0.2280 - accuracy: 0.9591 - val_loss: 6.3537 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 71/71 [==============================] - 1s 15ms/step - loss: 0.1947 - accuracy: 0.9734 - val_loss: 6.1587 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 71/71 [==============================] - 1s 15ms/step - loss: 0.1757 - accuracy: 0.9751 - val_loss: 5.8185 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.1472 - accuracy: 0.9858 - val_loss: 5.8273 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 71/71 [==============================] - 1s 13ms/step - loss: 0.1352 - accuracy: 0.9858 - val_loss: 6.0145 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.1264 - accuracy: 0.9893 - val_loss: 5.7195 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.1195 - accuracy: 0.9893 - val_loss: 6.0991 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.1079 - accuracy: 0.9947 - val_loss: 6.2537 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 71/71 [==============================] - 1s 14ms/step - loss: 0.1019 - accuracy: 0.9929 - val_loss: 6.1181 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'], label='Training accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracies')
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(128,128,1)),
        layers.Conv2D(4, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(16, activation="relu"),
        layers.Dense(num_cls, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 126, 126, 4)       40
#
#  max_pooling2d_1 (MaxPoolin  (None, 63, 63, 4)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 15876)             0
#
#  dense_2 (Dense)             (None, 16)                254032
#
#  dense_3 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 254140 (992.73 KB)
# Trainable params: 254140 (992.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 8
epochs = 20

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

hist=model.fit(x_train, label, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/20
# 71/71 [==============================] - 1s 13ms/step - loss: 1.3650 - accuracy: 0.2895 - val_loss: 1.4210 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 71/71 [==============================] - 1s 13ms/step - loss: 1.3720 - accuracy: 0.3375 - val_loss: 1.4848 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 71/71 [==============================] - 1s 11ms/step - loss: 1.3631 - accuracy: 0.3552 - val_loss: 1.5387 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 71/71 [==============================] - 1s 11ms/step - loss: 1.3547 - accuracy: 0.3552 - val_loss: 1.5939 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 71/71 [==============================] - 1s 12ms/step - loss: 1.3104 - accuracy: 0.3694 - val_loss: 1.9847 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 71/71 [==============================] - 1s 10ms/step - loss: 1.2000 - accuracy: 0.4849 - val_loss: 3.1746 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 71/71 [==============================] - 1s 11ms/step - loss: 1.0708 - accuracy: 0.5737 - val_loss: 3.1088 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 71/71 [==============================] - 1s 12ms/step - loss: 0.9214 - accuracy: 0.6590 - val_loss: 2.9141 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 71/71 [==============================] - 1s 13ms/step - loss: 0.7840 - accuracy: 0.7353 - val_loss: 3.5705 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 71/71 [==============================] - 1s 12ms/step - loss: 0.6299 - accuracy: 0.7904 - val_loss: 2.9781 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.5070 - accuracy: 0.8650 - val_loss: 3.2790 - val_accuracy: 0.0213
# Epoch 12/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.3252 - accuracy: 0.9254 - val_loss: 2.4938 - val_accuracy: 0.0851
# Epoch 13/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.2384 - accuracy: 0.9591 - val_loss: 1.8312 - val_accuracy: 0.2199
# Epoch 14/20
# 71/71 [==============================] - 1s 12ms/step - loss: 0.1572 - accuracy: 0.9769 - val_loss: 3.1504 - val_accuracy: 0.0426
# Epoch 15/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.0921 - accuracy: 0.9911 - val_loss: 4.0417 - val_accuracy: 0.0426
# Epoch 16/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.0630 - accuracy: 0.9964 - val_loss: 3.5836 - val_accuracy: 0.0496
# Epoch 17/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.0505 - accuracy: 0.9947 - val_loss: 4.7088 - val_accuracy: 0.0426
# Epoch 18/20
# 71/71 [==============================] - 1s 12ms/step - loss: 0.0361 - accuracy: 0.9982 - val_loss: 3.8778 - val_accuracy: 0.0638
# Epoch 19/20
# 71/71 [==============================] - 1s 11ms/step - loss: 0.0311 - accuracy: 0.9964 - val_loss: 4.4962 - val_accuracy: 0.0426
# Epoch 20/20
# 71/71 [==============================] - 1s 12ms/step - loss: 0.0330 - accuracy: 0.9964 - val_loss: 3.7101 - val_accuracy: 0.0567

# %%
plt.plot(hist.history['accuracy'], label='Training accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracies')
plt.legend()
plt.show()

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(128,128,1)),
        layers.Conv2D(16, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(16, activation="relu"),
        layers.Dense(num_cls, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 126, 126, 16)      160
#
#  max_pooling2d_2 (MaxPoolin  (None, 63, 63, 16)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 63504)             0
#
#  dense_4 (Dense)             (None, 16)                1016080
#
#  dense_5 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 1016308 (3.88 MB)
# Trainable params: 1016308 (3.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 8
epochs = 20

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

hist=model.fit(x_train, label, batch_size=batch_size, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/20
# 71/71 [==============================] - 2s 18ms/step - loss: 1.5871 - accuracy: 0.3108 - val_loss: 1.8728 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 71/71 [==============================] - 1s 18ms/step - loss: 1.2842 - accuracy: 0.3712 - val_loss: 2.0216 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 71/71 [==============================] - 1s 18ms/step - loss: 1.1911 - accuracy: 0.4671 - val_loss: 2.5455 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 71/71 [==============================] - 1s 19ms/step - loss: 1.0542 - accuracy: 0.5151 - val_loss: 2.7136 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 71/71 [==============================] - 2s 22ms/step - loss: 0.9405 - accuracy: 0.6021 - val_loss: 2.4844 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.8378 - accuracy: 0.6874 - val_loss: 2.9940 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.7204 - accuracy: 0.7531 - val_loss: 3.0203 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.6158 - accuracy: 0.7940 - val_loss: 4.8908 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.5142 - accuracy: 0.8313 - val_loss: 3.7981 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 71/71 [==============================] - 1s 18ms/step - loss: 0.4000 - accuracy: 0.9023 - val_loss: 3.8685 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 71/71 [==============================] - 1s 17ms/step - loss: 0.3057 - accuracy: 0.9396 - val_loss: 4.6197 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 71/71 [==============================] - 1s 18ms/step - loss: 0.2544 - accuracy: 0.9485 - val_loss: 7.1931 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 71/71 [==============================] - 1s 18ms/step - loss: 0.1875 - accuracy: 0.9680 - val_loss: 7.5799 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.1349 - accuracy: 0.9911 - val_loss: 6.6472 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 71/71 [==============================] - 1s 18ms/step - loss: 0.1149 - accuracy: 0.9929 - val_loss: 7.2682 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0854 - accuracy: 0.9929 - val_loss: 8.6409 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0612 - accuracy: 0.9982 - val_loss: 6.7608 - val_accuracy: 0.0071
# Epoch 18/20
# 71/71 [==============================] - 1s 20ms/step - loss: 0.0502 - accuracy: 0.9982 - val_loss: 9.0944 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0412 - accuracy: 0.9982 - val_loss: 9.9917 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 71/71 [==============================] - 1s 19ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 11.0449 - val_accuracy: 0.0000e+00

# %%
plt.plot(hist.history['accuracy'], label='Training accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracies')
plt.legend()
plt.show()

# %% [markdown]
# ## Describe and discuss what you observe by comparing the performance of the first model and the other two models you constructed in (a), (b) or (c) (depending on which one you did). Are there model overfit or underfit or just right?

# %% [markdown]
# # For all three models, its overfiting at the higher epochs as the difference between training accuracy and validation accuracy is very high. Model 2 performs better as the difference between training error and validiation error is not higher than other two.

# %% [markdown]
# # References

# %% [markdown]
# # http://rasbt.github.io/mlxtend/
# # http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
# # https://seaborn.pydata.org/generated/seaborn.heatmap.html
# # https://keras.io/examples/vision/mnist_convnet/
# # https://www.analyticsvidhya.com/blog/2021/01/image-classification-using-convolutional-neural-networks-a-step-by-step-guide/#:~:text=To%20use%20CNN%20for%20image,based%20on%20the%20learned%20features.
